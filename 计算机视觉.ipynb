# %% [markdown]
# # 基本的图像操作和处理
#
# 本章讲解操作和处理图像的基础知识，将通过大量示例介绍处理图像所需的 Python 工具包，并介绍用于读取图像、图像转换和缩放、计算导数、画图和保存结果等的基本工具。这些工具的使用将贯穿本书的剩余章节。

# %% [markdown]
# ## PIL：Python图像处理类库
# PIL（Python Imaging Library Python，图像处理类库）提供了通用的图像处理功能，以及大量有用的基本图像操作，比如图像缩放、裁剪、旋转、颜色转换等。PIL 是免费的。
#
# 利用 PIL 中的函数，我们可以从大多数图像格式的文件中读取数据，然后写入最常见的图像格式文件中。PIL 中最重要的模块为 Image。要读取一幅图像，可以使用：

# %%
# 加载PIL中的Image用于图像基本处理
from PIL import Image

# 图像显示
from matplotlib.pyplot import imshow

# pil_im执行后即可获得图像的二进制信息
pil_im = Image.open('empire.png')

# 显示图片
imshow(pil_im)

# %% [markdown]
# 上述代码的返回值 pil_im 是一个 PIL 图像对象。

# %% [markdown]
# # 灰度处理
#
# 图像的颜色转换可以使用 convert() 方法来实现。要读取一幅图像，并将其转换成灰度图像，只需要加上 convert('L')，如下所示：

# %%
pil_im = Image.open('empire.png').convert('L')
imshow(pil_im)

# %% [markdown]
# # 图像裁剪
#
# 使用 crop() 方法可以从一幅图像中裁剪指定区域：

# %%
box = (100,100,400,400)
im = Image.open('empire.png').crop(box)
imshow(im)

# %% [markdown]
# # 调整尺寸

# %%
im = Image.open('empire.png').resize((128,128))
imshow(im)

# %% [markdown]
# # 图像旋转

# %%
im = Image.open('empire.png').rotate(45)
imshow(im)

# %% [markdown]
# # 图像轮廓和直方图

# %%
# 加载PIL中的Image用于图像基本处理
from PIL import Image

# 图像显示
from matplotlib.pyplot import imshow

from pylab import *

# pil_im执行后即可获得图像的二进制信息
pil_im = Image.open('empire.png')
 
# 读取图像到数组中
im = array(pil_im.convert('L'))
 
# 新建一个图像
figure()
# 不使用颜色信息
gray()
# 在原点的左上角显示轮廓图像
contour(im, origin='image')
axis('equal')
axis('off')

figure()
hist(im.flatten(),128)
# Out:
# (array([   34.,   477.,   612.,   918.,   615.,   873.,   832.,   504.,
#           814.,   895.,   927.,   982.,  1481.,  1544.,  1396.,  1684.,
#          2293.,  2304.,  2310.,  1657.,  2594.,  2745.,  2896.,  3097.,
#          2262.,  3508.,  3593.,  3695.,  3334.,  3445.,  2763.,  3414.,
#          3283.,  3124.,  3159.,  3156.,  2936.,  2576.,  2947.,  3103.,
#          3271.,  3394.,  3128.,  3200.,  3002.,  2687.,  2694.,  3058.,
#          2985.,  3673.,  6554.,  7907.,  7866.,  9147., 10350., 10190.,
#          9433.,  8024.,  9351.,  9615.,  8330.,  7026.,  7433.,  7227.,
#          6865.,  5458.,  6387.,  6461.,  5391.,  5861.,  6851.,  6523.,
#          6120.,  5809.,  6147.,  5918.,  5847.,  6288.,  6167.,  6003.,
#          5867.,  5995.,  6244.,  6017.,  6014.,  5429.,  4903.,  4965.,
#          3263.,  1943.,  2164.,  2314.,  2622.,  2617.,  2744.,  2870.,
#          2697.,  2402.,  2392.,  2394.,  2329.,  2322.,  2395.,  2365.,
#          2274.,  2100.,  1779.,  1630.,  1384.,  1286.,  1188.,  1109.,
#          1003.,  1070.,  1146.,  1094.,  1072.,  1187.,  1470.,  1546.,
#          1977.,  1769.,  1975.,  2128.,  1579.,  1188.,  1440.,  3116.]),
#  array([  0.       ,   1.9921875,   3.984375 ,   5.9765625,   7.96875  ,
#           9.9609375,  11.953125 ,  13.9453125,  15.9375   ,  17.9296875,
#          19.921875 ,  21.9140625,  23.90625  ,  25.8984375,  27.890625 ,
#          29.8828125,  31.875    ,  33.8671875,  35.859375 ,  37.8515625,
#          39.84375  ,  41.8359375,  43.828125 ,  45.8203125,  47.8125   ,
#          49.8046875,  51.796875 ,  53.7890625,  55.78125  ,  57.7734375,
#          59.765625 ,  61.7578125,  63.75     ,  65.7421875,  67.734375 ,
#          69.7265625,  71.71875  ,  73.7109375,  75.703125 ,  77.6953125,
#          79.6875   ,  81.6796875,  83.671875 ,  85.6640625,  87.65625  ,
#          89.6484375,  91.640625 ,  93.6328125,  95.625    ,  97.6171875,
#          99.609375 , 101.6015625, 103.59375  , 105.5859375, 107.578125 ,
#         109.5703125, 111.5625   , 113.5546875, 115.546875 , 117.5390625,
#         119.53125  , 121.5234375, 123.515625 , 125.5078125, 127.5      ,
#         129.4921875, 131.484375 , 133.4765625, 135.46875  , 137.4609375,
#         139.453125 , 141.4453125, 143.4375   , 145.4296875, 147.421875 ,
#         149.4140625, 151.40625  , 153.3984375, 155.390625 , 157.3828125,
#         159.375    , 161.3671875, 163.359375 , 165.3515625, 167.34375  ,
#         169.3359375, 171.328125 , 173.3203125, 175.3125   , 177.3046875,
#         179.296875 , 181.2890625, 183.28125  , 185.2734375, 187.265625 ,
#         189.2578125, 191.25     , 193.2421875, 195.234375 , 197.2265625,
#         199.21875  , 201.2109375, 203.203125 , 205.1953125, 207.1875   ,
#         209.1796875, 211.171875 , 213.1640625, 215.15625  , 217.1484375,
#         219.140625 , 221.1328125, 223.125    , 225.1171875, 227.109375 ,
#         229.1015625, 231.09375  , 233.0859375, 235.078125 , 237.0703125,
#         239.0625   , 241.0546875, 243.046875 , 245.0390625, 247.03125  ,
#         249.0234375, 251.015625 , 253.0078125, 255.       ]),
#  <a list of 128 Patch objects>)
